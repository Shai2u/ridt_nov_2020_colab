# %%
import pandas as pd
import ipywidgets as widgets
from IPython.display import display
from ipywidgets.widgets.interaction import show_inline_matplotlib_plots
from ipywidgets import HBox, VBox
import numpy as np
import random
import uuid
import random
import datetime
import plotly.express as px
from plotly.subplots import make_subplots
import fiona
import geopandas as gpd
import folium
from folium.features import GeoJson, GeoJsonTooltip, GeoJsonPopup
import matplotlib.pyplot as plt; plt.rcdefaults()

pd.options.display.max_columns=25

# %%
def random_date(start_date,end_date):
    time_between_dates = end_date - start_date
    days_between_dates = time_between_dates.days
    random_number_of_days = random.randrange(days_between_dates)
    random_date_ = start_date + datetime.timedelta(days=random_number_of_days)

    return random_date_

# %%
def death_date(birth_date):
    #start_date = datetime.date(1920, 1, 1)
    #end_date = datetime.date(1950, 1, 1)
    random_number_of_days = random.randrange(60*365,stop=100*365)
    death_date_ = birth_date + datetime.timedelta(days=random_number_of_days)

    return death_date_

# %%
d =  datetime.date(1940, 1, 1)

# %%
def death_date_calculator(bd,a = 1.36,b = 68):
    mdy = int((bd.year-1900) * a + b) # mdy manhattan death year
    death_date_ = datetime.date(1900+mdy, 1, 1)
    random_number_of_days = np.random.normal(scale=0.4)*15*365 #+- 20 years
    death_date_ = death_date_ + datetime.timedelta(days=random_number_of_days)
    if (death_date_.year)<1975:
        death_date_ =  death_date_ + datetime.timedelta(days=(1975-death_date_.year)*365)
    return death_date_

# %%
def death_date_calculator2(ag,a = 1.36,b = 68):
    bd = ag.birth_date
    ed = ag['start_action']
    
    mdy = int((bd.year-1900) * a + b) # mdy manhattan death year
    death_date_ = datetime.date(1900+mdy, 1, 1)
    random_number_of_days = np.random.normal(scale=0.4)*15*365 #+- 20 years
    death_date_ = death_date_ + datetime.timedelta(days=random_number_of_days)
    if (death_date_)<ed:
        death_date_ =  death_date_ + datetime.timedelta(days=(ed.year-death_date_.year+random.randrange(1,5))*365)
    return death_date_

# %% [markdown]
# # Const (Later on put this in JSON) or put this in a form

# %%
p=[0.20,
 0.19, 
 0.18, 
 0.17, 
 0.16, 
 0.02, 
 0.05, 
 0.03, 
 0.0]
age_group = [22,30,40,50,57,62,70,80,90]

age_group_var = {
    22:2,
    30:5,
    40:5,
    50:5,
    57:2,
    62:2,
    70:5,
    80:5,
    90:5
}
p_elderly = [0.6,0.3,0.1]
age_group_elderly = [70,80,90]
last_year_of_simulation = 2050 # Define the last year of the simulaiton
end_of_simulation_date =  datetime.date(last_year_of_simulation, 1, 1)

# %%
np.sum(p)
# Out:
# 1.0

# %%
y_pos = np.arange(len(age_group))

plt.bar(y_pos, p, align='center', alpha=0.5)
plt.xticks(y_pos, age_group)
plt.ylabel('Percent')
plt.xlabel('Age groups')
plt.title('Simulated Distribution 1973')

plt.show()

# %%
def age_group_fun(num):
    return age_group_var[num]

# %%
def sample_elderly_age(pop_size):
    sam = np.random.choice(age_group_elderly, pop_size, p=p_elderly)
    sam_variance = np.array(list(map(age_group_fun, sam)))*np.random.normal(scale=0.37,size=pop_size)
    sam2 = sam + sam_variance
    return sam2.astype(int)

# %%
def sample_age_according_to_ri_pattern(pop_size):
    sam = np.random.choice(age_group, pop_size, p=p)
    sam_variance = np.array(list(map(age_group_fun, sam)))*np.random.normal(scale=0.37,size=pop_size)
    sam2 = sam + sam_variance
    return sam2.astype(int)

# %%
def sample_age_according_to_ri_pattern2(pop_size, ag = age_group,p_ = p):
    sam = np.random.choice(ag, pop_size, p=p_)
    sam_variance = np.array(list(map(age_group_fun, sam)))*np.random.normal(scale=0.37,size=pop_size)
    sam2 = sam + sam_variance
    return sam2.astype(int)

# %%
def birth_date(entrance_date):
    #start_date = datetime.date(1920, 1, 1)
    #end_date = datetime.date(1950, 1, 1)
    random_number_of_days = random.randrange(25*365,stop=65*365)
    birth_date_ = entrance_date - datetime.timedelta(days=random_number_of_days)

    return birth_date_

# %%
sam2 = sample_age_according_to_ri_pattern(1000)

# %%
plt.hist(sam2,12, facecolor='blue', alpha=0.5)
# Out:
# (array([262., 102., 104., 127.,  65.,  88.,  75.,  58.,  28.,  39.,  11.,
#          41.]),
#  array([19.        , 24.33333333, 29.66666667, 35.        , 40.33333333,
#         45.66666667, 51.        , 56.33333333, 61.66666667, 67.        ,
#         72.33333333, 77.66666667, 83.        ]),
#  <a list of 12 Patch objects>)

# %%
np.mean(sam2)
# Out:
# 39.611

# %%
# SUBPLOT!!!!
# plt.figure(figsize=(20, 7))
# ax1 = plt.subplot(121)
# x = sam
# num_bins = 9
# ax1.hist(x, num_bins, facecolor='blue', alpha=0.5)
# ax1.set_title('original')

# ax2 = plt.subplot(122)
# x = sam2
# num_bins = 9
# ax2 .hist(x, num_bins, facecolor='blue', alpha=0.5)
# ax2.set_title('Modified')



# plt.show()

# %%
death_date_calculator(d)
# Out:
# datetime.date(2012, 4, 16)

# %% [markdown]
# # Load Building Events

# %% [markdown]
# # Building Built TimeLine (GIS)

# %%
print('Enter Json Building Version: ')
bldg_json_wid = widgets.Text(value='bldgs_aug_24.geojson')
display(bldg_json_wid)
# Out:
# Enter Json Building Version:
# Text(value='bldgs_aug_24.geojson')

# %%
json_path = 'json/'+bldg_json_wid.value
json_bldgs = gpd.read_file(json_path, driver='GeoJSON')

# %%
json_bldgs
# Out:
#     fid          Bldg Proje  cnstrct_yr  feat_code  groundelev  heightroof  \
# 0     1      Manhattan park        1989       2100          11  186.620000
# 1     2         The Octagon        2006       2100          15  124.860000
# 2     3        island house        1975       2100          19  110.067359
# 3     4           The House        2017       2100          11  285.270000
# 4     5  Roosevelt Landings        1976       2100          14  178.331869
# 5     6          Rivercross        1975       2100          16  177.530000
# 6     7   Riverwalk Landing        2007       2100          17  192.853731
# 7     8     Riverwalk Point        2015       2100          15  150.000000
# 8     9            Westview        1975       2100          18  165.610000
# 9    10     Riverwalk place        2004       2100          23  181.830000
# 10   11     Riverwalk Court        2007       2100          17  192.853731
# 11   12  Riverwalk Crossing        2007       2100          17  192.853731
# 12   13      2-4 River Road        1989       2100          11  186.620000
# 13   14     Riverwalk place        2004       2100          23  181.830000
# 14   15     Riverwalk place        2004       2100          23  181.830000
# 15   16     Riverwalk Point        2020       2100          15  150.000000
#
#     name  rowID  Sharon Num                                  Address  \
# 0   None     23          20     10-40 River Road, New York, NY 10044
# 1   None     46         888      888 Main Street, New York, NY 10044
# 2   None      1         549  543-585 Main Street, New York, NY 10044
# 3   None      9          10                            1 E Loop Road
# 4   None     17         510  500-580 Main Street, New York, NY 10044
# 5   None     27         531  501-541 Main Street, New York, NY 10044
# 6   None      3         425      425 Main Street, New York, NY 10044
# 7   None     66         480      480 Main Street, New York, NY 10044
# 8   None     34         625  587-625 Main Street, New York, NY 10044
# 9   None     62         455     455  Main Street, New York, NY 10044
# 10  None      3         415      415 Main Street, New York, NY 10044
# 11  None      3         405      405 Main Street, New York, NY 10044
# 12  None     23          20       2-4 River Road, New York, NY 10044
# 13  None     62         465      465 Main Street, New York, NY 10044
# 14  None     62         475     475  Main Street, New York, NY 10044
# 15  None     66         460           460 Street, New York, NY 10044
#
#     Total Unit  Non_Afford  Afford_uni       Category bldgs_id  \
# 0          885         708         177         Rental    10-40
# 1          500         400         100         Rental      888
# 2          400           0         400  Rental & Coop  543_585
# 3          352           0         352         Rental      1_E
# 4         1003           0        1003         Rental  500_580
# 5          377           0         377           Coop  501_541
# 6          230         230           0    Rntal Condo      425
# 7          266         160         106         Rental      480
# 8          371           0         371         Rental  587_625
# 9          230         138          92          Condo      455
# 10         123         123           0    Rntal Condo      415
# 11         242         242           0    Rntal Condo      405
# 12         222           0         222         Rental      4_2
# 13         136          82          54          Condo      465
# 14         258         155         103          Condo      275
# 15         341         205         136         Rental      460
#
#     affordability_percent  elderly_affordable  non_elderly_affordable  \
# 0                     0.2                   0                     885
# 1                     0.2                   0                     500
# 2                     1.0                   0                     400
# 3                     1.0                   0                     352
# 4                     1.0                 300                     703
# 5                     1.0                   0                     377
# 6                     0.0                   0                     230
# 7                     0.4                   0                     266
# 8                     1.0                   0                     371
# 9                     0.4                   0                     230
# 10                    0.0                   0                     123
# 11                    0.0                   0                     242
# 12                    1.0                 111                     111
# 13                    0.4                   0                     136
# 14                    0.4                   0                     258
# 15                    0.4                   0                     341
#
#                                              geometry
# 0   MULTIPOLYGON (((-73.94732 40.76548, -73.94739 ...
# 1   MULTIPOLYGON (((-73.94389 40.76927, -73.94386 ...
# 2   MULTIPOLYGON (((-73.95031 40.76224, -73.95033 ...
# 3   MULTIPOLYGON (((-73.95523 40.75584, -73.95511 ...
# 4   MULTIPOLYGON (((-73.94947 40.76180, -73.94954 ...
# 5   MULTIPOLYGON (((-73.95141 40.76169, -73.95136 ...
# 6   MULTIPOLYGON (((-73.95279 40.75853, -73.95304 ...
# 7   MULTIPOLYGON (((-73.95168 40.75896, -73.95157 ...
# 8   MULTIPOLYGON (((-73.94872 40.76333, -73.94875 ...
# 9   MULTIPOLYGON (((-73.95237 40.75925, -73.95230 ...
# 10  MULTIPOLYGON (((-73.95338 40.75821, -73.95337 ...
# 11  MULTIPOLYGON (((-73.95436 40.75808, -73.95397 ...
# 12  MULTIPOLYGON (((-73.94851 40.76472, -73.94837 ...
# 13  MULTIPOLYGON (((-73.95205 40.75966, -73.95194 ...
# 14  MULTIPOLYGON (((-73.95179 40.76017, -73.95167 ...
# 15  MULTIPOLYGON (((-73.95135 40.75967, -73.95099 ...

# %% [markdown]
# # Build Synthetic Agents

# %%
for i in (json_bldgs.index):
    cb = json_bldgs.loc[i]#current building
    total_agents = cb['Total Unit']
    bld_key = [cb['bldgs_id']]*total_agents

    agent_dict = {'app_index' : [i for i in range(total_agents)],
                  'bld_key' : bld_key} # define the dictionary for the dataset

    App_datasets = pd.DataFrame.from_dict(agent_dict)
    App_datasets['address_door']=App_datasets['bld_key']+"_"+App_datasets['app_index'].astype(str)
    App_datasets['Agent_Status']='Living'
    App_datasets['agent_action']= "Entered Building"
    construct_year = datetime.date(cb['cnstrct_yr'], 1, 1)
    App_datasets['start_action']= construct_year
    App_datasets['end_action']= datetime.date(cb['cnstrct_yr'], 1, 2)
    #App_datasets['birth_date'] = App_datasets['start_action'].apply(birth_date)
    ages_in_building = sample_age_according_to_ri_pattern(total_agents)
    App_datasets['birth_date'] = [ construct_year - datetime.timedelta(days=int(age)*365) for age in ages_in_building ]
    App_datasets['death_date'] = App_datasets.apply(death_date_calculator2,axis=1)
    App_datasets['death_age'] = (((App_datasets['death_date'] - App_datasets['birth_date']).dt.days)/365).astype(int)
    App_datasets['entrance_age'] = (((construct_year - App_datasets['birth_date']).dt.days)/365).astype(int)
    App_datasets['affordable_living'] = 0
    App_datasets['elderly_lving'] = 0
    App_datasets.loc[0:cb['Afford_uni'],'affordable_living'] = 1
    ela = cb['elderly_affordable'] #elderly living agents
    if ela>0:
        App_datasets.loc[0:ela,'elderly_lving'] = 1
        old_ages_in_building = sample_age_according_to_ri_pattern2(ela+1,age_group_elderly,p_elderly)
        con1 = App_datasets['elderly_lving']==1 #affordable living CONDITION
        App_datasets.loc[con1, 'birth_date'] = [ construct_year - datetime.timedelta(days=int(age)*365) for age in old_ages_in_building ]
        App_datasets.loc[con1,'death_date'] = App_datasets.loc[con1].apply(death_date_calculator2,axis=1)
        App_datasets.loc[con1,'death_age'] = (((App_datasets.loc[con1,'death_date'] - App_datasets.loc[con1,'birth_date']).dt.days)/365).astype(int)
        App_datasets.loc[con1,'entrance_age'] = (((construct_year - App_datasets.loc[con1,'birth_date']).dt.days)/365).astype(int)

    #App_dataset[Renter,owner/Condo,Coop]
    #App_dataset[income]
    #Wire were ha
    
    
    
    if (i==0): # First iteration
        df = App_datasets
        #total_agents = cb['Total Unit']
    else:
        frames = [df,App_datasets]
        df = pd.concat(frames)
df.reset_index(inplace=True,drop=True)
df['agentID'] = [uuid.uuid4() for _ in range(len(df.index))]
df['previous_agentID']='0'

# %%
df['entrance_age'].hist()

# %%
#df.loc[df['bld_key']=='500_580']['death_age'].hist()
df.loc[df['bld_key']=='500_580']['entrance_age'].hist()

# %%
json_bldgs[json_bldgs['cnstrct_yr']<2003]['Total Unit'].sum()
# Out:
# 3258

# %%
json_bldgs['Total Unit'].sum()
# Out:
# 5936

# %%
#Select building where elderly live
elderly_set = json_bldgs[json_bldgs['elderly_affordable']>0][['bldgs_id','elderly_affordable']]
elderly_set.reset_index(inplace=True)

# %%
elderly_set
# Out:
#    index bldgs_id  elderly_affordable
# 0      4  500_580                 300
# 1     12      4_2                 111

# %% [markdown]
# ### Add Dead Agents for the first time

# %%
# # Create Death Event for all agents the first time
# df_addition = df.copy()
# df_addition['Agent_Status'] = "Dead"
# df_addition['agent_action'] = "Died"
# df_addition['start_action'] = df_addition['death_date']
# df_addition['end_action'] = datetime.date(2100, 1, 1)
# df = pd.concat([df,df_addition])
# df.reset_index(inplace=True, drop=True)

# %% [markdown]
# ### Simulate Agent Dynamics based on Dead AGents
# ### 1. Mark the dead agents as a new event in the dynaic Population (also add it to an avent diary)
# ### 2. List vacanat appartment
# ### 3. Generate new Agents who will populate the old appartment
# ### 4. Check if Appartment is not "elderly"

# %%
# Check the number of total units in 2050
print('Number of Total Units in 2050: ', json_bldgs['Total Unit'].sum())
# Out:
# Number of Total Units in 2050:  5936

# %%
for year in range(1975,2021):
    print('for the year: ', year)
    tnu = json_bldgs[json_bldgs['cnstrct_yr']<=year]['Total Unit'].sum() # total number of units
    current_year_df =df[df['start_action']<datetime.date(year, 2, 1)]
    living_agents = current_year_df[current_year_df['death_date']>datetime.date(year, 1, 1)]['agentID'].count()
    dead_agents = current_year_df[current_year_df['death_date']<datetime.date(year, 1, 1)]['agentID'].count()
    print('total Number of untis: ', tnu)
    print('Total Number of Agents: ', living_agents+dead_agents)
    print('Active Living Agents: ', living_agents)
# Out:
# for the year:  1975
# total Number of untis:  1148
# Total Number of Agents:  1148
# Active Living Agents:  1148
# for the year:  1976
# total Number of untis:  2151
# Total Number of Agents:  2151
# Active Living Agents:  2147
# for the year:  1977
# total Number of untis:  2151
# Total Number of Agents:  2151
# Active Living Agents:  2109
# for the year:  1978
# total Number of untis:  2151
# Total Number of Agents:  2150
# Active Living Agents:  2019
# for the year:  1979
# total Number of untis:  2151
# Total Number of Agents:  2151
# Active Living Agents:  1921
# for the year:  1980
# total Number of untis:  2151
# Total Number of Agents:  2150
# Active Living Agents:  1817
# for the year:  1981
# total Number of untis:  2151
# Total Number of Agents:  2151
# Active Living Agents:  1730
# for the year:  1982
# total Number of untis:  2151
# Total Number of Agents:  2151
# Active Living Agents:  1710
# for the year:  1983
# total Number of untis:  2151
# Total Number of Agents:  2151
# Active Living Agents:  1693
# for the year:  1984
# total Number of untis:  2151
# Total Number of Agents:  2151
# Active Living Agents:  1680
# for the year:  1985
# total Number of untis:  2151
# Total Number of Agents:  2151
# Active Living Agents:  1663
# for the year:  1986
# total Number of untis:  2151
# Total Number of Agents:  2151
# Active Living Agents:  1646
# for the year:  1987
# total Number of untis:  2151
# Total Number of Agents:  2151
# Active Living Agents:  1625
# for the year:  1988
# total Number of untis:  2151
# Total Number of Agents:  2151
# Active Living Agents:  1610
# for the year:  1989
# total Number of untis:  3258
# Total Number of Agents:  3258
# Active Living Agents:  2696
# for the year:  1990
# total Number of untis:  3258
# Total Number of Agents:  3258
# Active Living Agents:  2669
# for the year:  1991
# total Number of untis:  3258
# Total Number of Agents:  3258
# Active Living Agents:  2608
# for the year:  1992
# total Number of untis:  3258
# Total Number of Agents:  3258
# Active Living Agents:  2554
# for the year:  1993
# total Number of untis:  3258
# Total Number of Agents:  3258
# Active Living Agents:  2494
# for the year:  1994
# total Number of untis:  3258
# Total Number of Agents:  3258
# Active Living Agents:  2439
# for the year:  1995
# total Number of untis:  3258
# Total Number of Agents:  3257
# Active Living Agents:  2396
# for the year:  1996
# total Number of untis:  3258
# Total Number of Agents:  3258
# Active Living Agents:  2353
# for the year:  1997
# total Number of untis:  3258
# Total Number of Agents:  3258
# Active Living Agents:  2316
# for the year:  1998
# total Number of untis:  3258
# Total Number of Agents:  3258
# Active Living Agents:  2278
# for the year:  1999
# total Number of untis:  3258
# Total Number of Agents:  3258
# Active Living Agents:  2245
# for the year:  2000
# total Number of untis:  3258
# Total Number of Agents:  3258
# Active Living Agents:  2204
# for the year:  2001
# total Number of untis:  3258
# Total Number of Agents:  3258
# Active Living Agents:  2157
# for the year:  2002
# total Number of untis:  3258
# Total Number of Agents:  3258
# Active Living Agents:  2120
# for the year:  2003
# total Number of untis:  3258
# Total Number of Agents:  3257
# Active Living Agents:  2087
# for the year:  2004
# total Number of untis:  3882
# Total Number of Agents:  3882
# Active Living Agents:  2681
# for the year:  2005
# total Number of untis:  3882
# Total Number of Agents:  3882
# Active Living Agents:  2647
# for the year:  2006
# total Number of untis:  4382
# Total Number of Agents:  4382
# Active Living Agents:  3101
# for the year:  2007
# total Number of untis:  4977
# Total Number of Agents:  4977
# Active Living Agents:  3667
# for the year:  2008
# total Number of untis:  4977
# Total Number of Agents:  4976
# Active Living Agents:  3617
# for the year:  2009
# total Number of untis:  4977
# Total Number of Agents:  4977
# Active Living Agents:  3578
# for the year:  2010
# total Number of untis:  4977
# Total Number of Agents:  4977
# Active Living Agents:  3519
# for the year:  2011
# total Number of untis:  4977
# Total Number of Agents:  4977
# Active Living Agents:  3479
# for the year:  2012
# total Number of untis:  4977
# Total Number of Agents:  4977
# Active Living Agents:  3428
# for the year:  2013
# total Number of untis:  4977
# Total Number of Agents:  4977
# Active Living Agents:  3385
# for the year:  2014
# total Number of untis:  4977
# Total Number of Agents:  4977
# Active Living Agents:  3342
# for the year:  2015
# total Number of untis:  5243
# Total Number of Agents:  5243
# Active Living Agents:  3570
# for the year:  2016
# total Number of untis:  5243
# Total Number of Agents:  5243
# Active Living Agents:  3520
# for the year:  2017
# total Number of untis:  5595
# Total Number of Agents:  5595
# Active Living Agents:  3825
# for the year:  2018
# total Number of untis:  5595
# Total Number of Agents:  5595
# Active Living Agents:  3776
# for the year:  2019
# total Number of untis:  5595
# Total Number of Agents:  5595
# Active Living Agents:  3737
# for the year:  2020
# total Number of untis:  5936
# Total Number of Agents:  5936
# Active Living Agents:  4024

# %%
choose_year = 2000
test_con = ((df['Agent_Status']=='Living') & (((df['birth_date']) < datetime.date(choose_year, 1, 1)) & ((df['death_date'])> datetime.date(choose_year, 1, 1))))
agent_count = df.loc[test_con]['agentID'].count()
print('Number of living Agents in '+str(choose_year)+': ' + str(agent_count))
# Out:
# Number of living Agents in 2000: 4887

# %%
con_1 = ((df['Agent_Status']=='Living') & (((df['birth_date']) < end_of_simulation_date) & ((df['death_date'])> end_of_simulation_date)))
agent_count = df.loc[con_1]['agentID'].count()
print('Number of living Agents in 2050: ', agent_count)
# Out:
# Number of living Agents in 2050:  2114

# %%
print('Number of Dead Agents in 2050: ' + str(new_agents['agentID'].count()))
# Out:
# Number of Dead Agents in 2050: 826

# %%
new_agents['agentID'].count() < 50
# Out:
# False

# %%
new_agents = df.loc[((df['Agent_Status']=='Dead') & (df['death_date']<datetime.date(2050, 1, 1)))].copy()
print('Number of Dead Agents in 2050: ' + str(new_agents['agentID'].count()))
iteration = 0
new_agents_accumulator = pd.DataFrame()
print("in")

while ((iteration <4)):

    if (iteration > 0):
        new_agents_accumulator = pd.concat([new_agents_accumulator,new_agents])
        new_agents = new_agents.loc[((new_agents['Agent_Status']=='Dead') & (new_agents['death_date']<datetime.date(2050, 1, 1)))].copy()
        new_agents = new_agents.loc[new_agents['previous_agentID']=='0'].copy()
    
    print('Iteration '+str(iteration))
    
    # Copy ID of the Dead Agent who will be the previous agent Now
    new_agents['previous_agentID'] = new_agents['agentID']
    new_agents['agentID'] = [uuid.uuid4() for _ in range(len(new_agents.index))] # New Agent ID

    # Make the agent live and let him move in to the old house
    new_agents['Agent_Status']='Living'
    new_agents['agent_action']= "Entered Building"
    new_agents['start_action'] = new_agents['death_date'].apply(lambda x: x + datetime.timedelta(days=int(1)))
    new_agents['end_action'] = new_agents['start_action'].apply(lambda x: x + datetime.timedelta(days=int(1)))

    #ages_in_building = sample_age_according_to_ri_pattern(total_agents)
    con0 = new_agents['elderly_lving']==0 # young agents
    ne_ac = new_agents.loc[(con0),'agentID'].count() # Non Eldery Age Count
    if ne_ac > 0:
        ages_in_building = sample_age_according_to_ri_pattern2(ne_ac,age_group,p)

        entrance_year = pd.to_datetime(new_agents.loc[(con0),'start_action']).dt.year
        birth_year = entrance_year - ages_in_building
        new_agents.loc[(con0),'birth_date'] = [ datetime.date(i, 1, 1) for i in birth_year ]
        new_agents.loc[(con0),'death_date'] = new_agents.loc[(con0)].apply(death_date_calculator2,axis=1)

        new_agents.loc[(con0),'death_age'] = (((
            new_agents.loc[(con0),'death_date'] - new_agents.loc[(con0),'birth_date']).dt.days)/365).astype(int)

        new_agents.loc[(con0),'entrance_age'] = (
            pd.to_datetime(new_agents.loc[(con0),'start_action']).dt.year - 
            pd.to_datetime(new_agents.loc[(con0),'birth_date']).dt.year)



    # SubSet for Elderly Agents
    con1 = new_agents['elderly_lving']==1 # elderly living condition 1
    e_ac = new_agents.loc[(con1),'agentID'].count() # Eldery Age Count
    if e_ac > 0:
        old_ages_in_building = sample_age_according_to_ri_pattern2(e_ac,age_group_elderly,p_elderly)

        entrance_year2 = pd.to_datetime(new_agents.loc[(con1),'start_action']).dt.year
        birth_year2 = entrance_year2 - old_ages_in_building
        new_agents.loc[(con1),'birth_date'] = [ datetime.date(i, 1, 1) for i in birth_year2 ]
        new_agents.loc[(con1),'death_date'] = new_agents.loc[new_agents['elderly_lving']==1].apply(death_date_calculator2,axis=1)

        new_agents.loc[(con1),'death_age'] = (((
            new_agents.loc[(con1),'death_date'] - new_agents.loc[(con1),'birth_date']).dt.days)/365).astype(int)

        new_agents.loc[new_agents['elderly_lving']==1,'entrance_age'] = (
            pd.to_datetime(new_agents.loc[(con1),'start_action']).dt.year - 
            pd.to_datetime(new_agents.loc[(con1),'birth_date']).dt.year
            )
    if ((e_ac+ne_ac)>0):
        new_agents_2 = new_agents.copy()
        new_agents_2['Agent_Status'] = "Dead"
        new_agents_2['agent_action'] = "Died"
        new_agents_2['start_action'] = new_agents['death_date']
        new_agents_2['end_action'] = datetime.date(2100, 1, 1)
        new_agents_2['previous_agentID'] = '0'
        new_agents = pd.concat([new_agents,new_agents_2])
        new_agents.reset_index(inplace=True, drop=True)
        iteration = iteration +1
    else:
        iteration = 100
# Out:
# Number of Dead Agents in 2050: 3821
# in
# Iteration 0
# Iteration 1
# Iteration 2
# Iteration 3

# %%
print('Number of Dead Agents in 2050: ' + str(new_agents['agentID'].count()))
# Out:
# Number of Dead Agents in 2050: 836

# %%
new_agents_accumulator.reset_index(inplace=True, drop=True)

# %%
new_agents_accumulator =  new_agents_accumulator.loc[new_agents_accumulator['start_action']<datetime.date(2050, 1, 1)] # Limit Simulation to 2050

# %%
df_2 = pd.concat([df,new_agents_accumulator])
df_2.reset_index(inplace=True,drop=True)

# %%
df_2.head()
df_2.to_excel('df2.xlsx')

# %%
new_agents_accumulator.to_excel('nac.xlsx')

# %% [markdown]
# # Get to know the Agents

# %%
select_year_widget = widgets.IntSlider(
    value=1980,
    min=1975,
    max=2050,
    step=1,
    disabled=False,
    description='Year',
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='d'
)
print('Select year to show Agent Statistics:')
display(select_year_widget)
# Out:
# Select year to show Agent Statistics:
# IntSlider(value=1980, continuous_update=False, description='Year', max=2050, min=1975)

# %%
year_pick = select_year_widget.value
current_date_range_1 =  datetime.date(year_pick, 1, 1)
current_date_range_2 =  datetime.date(year_pick, 3, 1)
#select dead agents
#df_filter = df.loc[(df['start_action']<current_date_range_2) & (df['start_action']>=current_date_range_1) & (df['Agent_Status']=='Living')]
df_filter1 = df_2.loc[(df_2['Agent_Status']=='Living') & (df_2['start_action']<current_date_range_2)]

dead_agents = df_filter1.loc[current_date_range_1>df_filter1['death_date']]
living_agents = df_filter1.loc[(current_date_range_2<df_filter1['death_date']) & (current_date_range_2>df_filter1['birth_date'])]
#statistics for lviing agents
agent_age = (current_date_range_1 - living_agents['birth_date']).dt.days
agent_age = agent_age.apply(lambda x: int(float(x)/365))
agent_age.name='Age'
fig = px.box(agent_age, y="Age",title="Age")
print('')
print('')
print('year: ', str(year_pick))

fig1 = px.histogram(agent_age, x="Age",title="Age Histogram")

print('Average Age of Household: ',int(agent_age.mean()))
print('Number of Households: ',int(agent_age.count()))
print("Number of Agents displaced: 0")
print("Number of Agents who died ",dead_agents['agentID'].count())
print("Life Expectancy Average",round(df['death_age'].mean(),1))
trace1 = fig['data'][0]
trace2 = fig1['data'][0]

fig = make_subplots(rows=1, cols=2, shared_xaxes=False,subplot_titles=['Age','Age Histogram'])
fig.add_trace(trace1, row=1, col=1)
fig.add_trace(trace2, row=1, col=2)
# Out:
# year:  2003
# Average Age of Household:  55
# Number of Households:  2956
# Number of Agents displaced: 0
# Number of Agents who died  2281
# Life Expectancy Average 85.9

# %%
Current_Age = ((current_date_range_1 - living_agents['birth_date']).dt.days/365).astype(int)
ca = pd.DataFrame(Current_Age)
ca['Group age'] = ca['birth_date'].apply(get_group_category)
ca = ca.groupby('Group age').agg({'birth_date':'count'}).reset_index()
ca.rename(columns = {'birth_date':'count'},inplace=True)
ca['count']=ca['count']*2
ca
# Out:
#    Group age  count
# 0       22.0     60
# 1       30.0    468
# 2       40.0    770
# 3       50.0   1592
# 4       57.0    742
# 5       62.0    630
# 6       70.0   1228
# 7       80.0    414
# 8       90.0      6

# %%
ca['count'].sum()
# Out:
# 5910

# %%
ca.plot.bar(x='Group age')

# %%
def get_group_category(x):
    if (x>85):
        return 90
    elif (x>75):
        return 80
    elif (x>65):
        return 70
    elif (x>60):
        return 62
    elif (x>55):
        return 57
    elif (x>45):
        return 50
    elif(x>35):
        return 40
    elif(x>25):
        return 30
    elif(x>20):
        return 22

# %% [markdown]
# ## Pivoting Agents to Buildings according to the time

# %%
living_agents = living_agents.copy()
dead_agents = dead_agents.copy()

living_agents['age']=(current_date-living_agents['birth_date']).dt.days
living_agents['age'] = living_agents['age'].apply(lambda x: int(float(x)/365))

la_groups = living_agents.groupby('bld_key') #living agents group by
d_groups = dead_agents.groupby('bld_key') #dead agents group by

la_pivot = la_groups.agg({'agentID':['count'],
              'age':['mean'],'affordable_living':['sum']})

d_pivot = d_groups.agg({'agentID':['count']})

la_pivot.columns = ['Number of Living Agents','Mean Age', 'Affordable Living']
d_pivot.columns = ['Number of Dead Agents']

la_pivot.reset_index(inplace=True)
d_pivot.reset_index(inplace=True)
la_pivot['Affordable_ratio'] = (la_pivot['Affordable Living']/la_pivot['Number of Living Agents']).apply(lambda x:round(x,2))

agents_age = pd.merge(la_pivot,d_pivot,on='bld_key')

jbbf1 = pd.merge(json_bldgs,agents_age,left_on='bldgs_id', right_on='bld_key',how='right')

jbbf1['Mean Age'] = jbbf1['Mean Age'].astype(int)

# %%
jbbf1
# Out:
#     fid          Bldg Proje  cnstrct_yr  feat_code  groundelev  heightroof  \
# 0     1      Manhattan park        1989       2100          11  186.620000
# 1     4           The House        2017       2100          11  285.270000
# 2    15     Riverwalk place        2004       2100          23  181.830000
# 3    12  Riverwalk Crossing        2007       2100          17  192.853731
# 4    11     Riverwalk Court        2007       2100          17  192.853731
# 5     7   Riverwalk Landing        2007       2100          17  192.853731
# 6    10     Riverwalk place        2004       2100          23  181.830000
# 7    14     Riverwalk place        2004       2100          23  181.830000
# 8     8     Riverwalk Point        2015       2100          15  150.000000
# 9    13      2-4 River Road        1989       2100          11  186.620000
# 10    5  Roosevelt Landings        1976       2100          14  178.331869
# 11    6          Rivercross        1975       2100          16  177.530000
# 12    3        island house        1975       2100          19  110.067359
# 13    9            Westview        1975       2100          18  165.610000
# 14    2         The Octagon        2006       2100          15  124.860000
#
#     name  rowID  Sharon Num                                  Address  \
# 0   None     23          20     10-40 River Road, New York, NY 10044
# 1   None      9          10                            1 E Loop Road
# 2   None     62         475     475  Main Street, New York, NY 10044
# 3   None      3         405      405 Main Street, New York, NY 10044
# 4   None      3         415      415 Main Street, New York, NY 10044
# 5   None      3         425      425 Main Street, New York, NY 10044
# 6   None     62         455     455  Main Street, New York, NY 10044
# 7   None     62         465      465 Main Street, New York, NY 10044
# 8   None     66         480      480 Main Street, New York, NY 10044
# 9   None     23          20       2-4 River Road, New York, NY 10044
# 10  None     17         510  500-580 Main Street, New York, NY 10044
# 11  None     27         531  501-541 Main Street, New York, NY 10044
# 12  None      1         549  543-585 Main Street, New York, NY 10044
# 13  None     34         625  587-625 Main Street, New York, NY 10044
# 14  None     46         888      888 Main Street, New York, NY 10044
#
#     Total Unit  Non_Afford  Afford_uni       Category bldgs_id  \
# 0          885         708         177         Rental    10-40
# 1          352           0         352         Rental      1_E
# 2          258         155         103          Condo      275
# 3          242         242           0    Rntal Condo      405
# 4          123         123           0    Rntal Condo      415
# 5          230         230           0    Rntal Condo      425
# 6          230         138          92          Condo      455
# 7          136          82          54          Condo      465
# 8          266         160         106         Rental      480
# 9          222           0         222         Rental      4_2
# 10        1003           0        1003         Rental  500_580
# 11         377           0         377           Coop  501_541
# 12         400           0         400  Rental & Coop  543_585
# 13         371           0         371         Rental  587_625
# 14         500         400         100         Rental      888
#
#     affordability_percent  elderly_affordable  non_elderly_affordable  \
# 0                     0.2                   0                     885
# 1                     1.0                   0                     352
# 2                     0.4                   0                     258
# 3                     0.0                   0                     242
# 4                     0.0                   0                     123
# 5                     0.0                   0                     230
# 6                     0.4                   0                     230
# 7                     0.4                   0                     136
# 8                     0.4                   0                     266
# 9                     1.0                 111                     111
# 10                    1.0                 300                     703
# 11                    1.0                   0                     377
# 12                    1.0                   0                     400
# 13                    1.0                   0                     371
# 14                    0.2                   0                     500
#
#                                              geometry  bld_key  \
# 0   MULTIPOLYGON (((-73.94732 40.76548, -73.94739 ...    10-40
# 1   MULTIPOLYGON (((-73.95523 40.75584, -73.95511 ...      1_E
# 2   MULTIPOLYGON (((-73.95179 40.76017, -73.95167 ...      275
# 3   MULTIPOLYGON (((-73.95436 40.75808, -73.95397 ...      405
# 4   MULTIPOLYGON (((-73.95338 40.75821, -73.95337 ...      415
# 5   MULTIPOLYGON (((-73.95279 40.75853, -73.95304 ...      425
# 6   MULTIPOLYGON (((-73.95237 40.75925, -73.95230 ...      455
# 7   MULTIPOLYGON (((-73.95205 40.75966, -73.95194 ...      465
# 8   MULTIPOLYGON (((-73.95168 40.75896, -73.95157 ...      480
# 9   MULTIPOLYGON (((-73.94851 40.76472, -73.94837 ...      4_2
# 10  MULTIPOLYGON (((-73.94947 40.76180, -73.94954 ...  500_580
# 11  MULTIPOLYGON (((-73.95141 40.76169, -73.95136 ...  501_541
# 12  MULTIPOLYGON (((-73.95031 40.76224, -73.95033 ...  543_585
# 13  MULTIPOLYGON (((-73.94872 40.76333, -73.94875 ...  587_625
# 14  MULTIPOLYGON (((-73.94389 40.76927, -73.94386 ...      888
#
#     Number of Living Agents  Mean Age  Affordable Living  Affordable_ratio  \
# 0                       884        16                178              0.20
# 1                       352         5                352              1.00
# 2                       258        14                104              0.40
# 3                       242        13                  1              0.00
# 4                       123        10                  1              0.01
# 5                       230        12                  1              0.00
# 6                       230        13                 93              0.40
# 7                       136        14                 55              0.40
# 8                       266         4                107              0.40
# 9                       127        18                127              1.00
# 10                      699        18                699              1.00
# 11                      376        18                376              1.00
# 12                      399        17                399              1.00
# 13                      369        18                369              1.00
# 14                      500        12                101              0.20
#
#     Number of Dead Agents
# 0                     426
# 1                       2
# 2                      36
# 3                      20
# 4                       7
# 5                      16
# 6                      28
# 7                      13
# 8                       7
# 9                     482
# 10                   1859
# 11                    350
# 12                    395
# 13                    355
# 14                     29

# %%
df.head()
# Out:
#    app_index bld_key address_door Agent_Status      agent_action start_action  \
# 0          0   10-40      10-40_0       Living  Entered Building   1989-01-01
# 1          1   10-40      10-40_1       Living  Entered Building   1989-01-01
# 2          2   10-40      10-40_2       Living  Entered Building   1989-01-01
# 3          3   10-40      10-40_3       Living  Entered Building   1989-01-01
# 4          4   10-40      10-40_4       Living  Entered Building   1989-01-01
#
#    end_action  birth_date  death_date  death_age  entrance_age  \
# 0  1989-01-02  1958-01-09  2044-06-24         86            31
# 1  1989-01-02  1936-01-15  2008-06-22         72            53
# 2  1989-01-02  1958-01-09  2048-06-23         90            31
# 3  1989-01-02  1957-01-09  2051-11-11         94            32
# 4  1989-01-02  1932-01-16  2003-09-20         71            57
#
#    affordable_living  elderly_lving                               agentID  \
# 0                  1              0  2d577a86-bba3-4604-8cc0-65b91a17f4d6
# 1                  1              0  77a7ca2b-f9bd-4553-b38f-0c3a74d68317
# 2                  1              0  cb1dd29e-eccb-458d-afa2-03327d184d44
# 3                  1              0  cebd99f3-56b2-4036-bc50-02cad800cc6c
# 4                  1              0  762479cb-075c-4c23-b381-98853d04db42
#
#   previous_agentID
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0

# %% [markdown]
# ## Creating Map with colorpleth

# %%
import branca.colormap as cm
linear = cm.LinearColormap(
    ['green', 'yellow', 'red'],
    vmin=0, vmax=1
)

# %%
#examples
#https://nbviewer.jupyter.org/github/python-visualization/folium/blob/master/examples/GeoJSON_and_choropleth.ipynb
#https://nbviewer.jupyter.org/github/python-visualization/folium/blob/master/examples/GeoJSON_and_choropleth.ipynb

#year_pick = select_year_widget.value
#json_bldgs_built_filter = json_bldgs.loc[json_bldgs['cnstrct_yr']<=year_pick]
m = folium.Map([40.762, -73.955], zoom_start=16, tiles='cartodbpositron')
popup = GeoJsonPopup(
    fields=['Number of Living Agents','Number of Dead Agents','Mean Age','Affordable_ratio'],
    aliases=['Number of Living Agents:',"Number of Agents who died:",'Mean Age:','Affordable Percent:'],

    localize=True,
    labels=True,
    style="background-color: yellow;",
)

tooltip = GeoJsonTooltip(
    fields=['Bldg Proje','Address'],
    aliases=['Building Project',"Address"],
    localize=True,
    sticky=False,
    labels=True,
    style="""
        background-color: #F0EFEF;
        border: 2px solid black;
        border-radius: 3px;
        box-shadow: 3px;
    """,
    max_width=800,
)

folium.Tooltip = tooltip
folium.Popup = popup

folium.GeoJson(jbbf1,
   style_function=lambda feature: {
       'fillColor': linear(feature['properties']['Affordable_ratio']),
       'color': 'black',
       'weight': 1
   },tooltip=tooltip,
               popup=popup).add_to(m)
folium.LayerControl().add_to(m)
linear.caption = 'Affordable Living'
linear.add_to(m)



#folium.GeoJson(jbbf1,
#   style_function=lambda feature: {
#       'fillColor': '#cfcfcf',
#       'color': 'black',
#       'weight': 1
#   },tooltip=tooltip,
#   popup=popup
#             ).add_to(m)
#m.save('year_1979.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#dead_agents
living_agents
# Out:
#       app_index  bld_key address_door Agent_Status      agent_action  \
# 1385          0  543_585    543_585_0       Living  Entered Building
# 1386          1  543_585    543_585_1       Living  Entered Building
# 1387          2  543_585    543_585_2       Living  Entered Building
# 1388          3  543_585    543_585_3       Living  Entered Building
# 1389          4  543_585    543_585_4       Living  Entered Building
# ...         ...      ...          ...          ...               ...
# 4379        366  587_625  587_625_366       Living  Entered Building
# 4380        367  587_625  587_625_367       Living  Entered Building
# 4381        368  587_625  587_625_368       Living  Entered Building
# 4382        369  587_625  587_625_369       Living  Entered Building
# 4383        370  587_625  587_625_370       Living  Entered Building
#
#      start_action  end_action  birth_date  death_date  \
# 1385   1975-01-01  1975-03-01  1920-09-04  1989-11-03
# 1386   1975-01-01  1975-03-01  1915-08-04  1980-04-27
# 1387   1975-01-01  1975-03-01  1933-03-11  2007-02-28
# 1388   1975-01-01  1975-03-01  1937-07-10  2009-09-07
# 1389   1975-01-01  1975-03-01  1936-09-15  2010-01-24
# ...           ...         ...         ...         ...
# 4379   1975-01-01  1975-03-01  1938-01-07  2011-02-04
# 4380   1975-01-01  1975-03-01  1921-05-30  2019-08-02
# 4381   1975-01-01  1975-03-01  1944-07-01  2028-03-11
# 4382   1975-01-01  1975-03-01  1934-01-09  2000-03-18
# 4383   1975-01-01  1975-03-01  1915-09-03  2015-03-24
#
#                                    agentID
# 1385  b0708e81-201f-4323-90b4-35165018eaec
# 1386  4b64f55e-e353-4421-a0b7-bd7e17ea08fe
# 1387  df596a70-d631-482e-b109-00ac06feecb3
# 1388  9fa2797b-69bc-49b0-a082-571613566880
# 1389  f3c0d48e-7403-482b-bc15-846afff843f1
# ...                                    ...
# 4379  93768326-c66a-4598-aab5-d520f87898b7
# 4380  f030b772-18b9-482d-ae5b-106bf6fbba36
# 4381  8c1c6169-ed20-47e6-ae88-9f1d71830902
# 4382  24328418-a9f1-4d8d-a753-72a1376b6ae0
# 4383  7be4d51f-a5a5-416d-835f-ca030e550eec
#
# [2100 rows x 10 columns]

# %%
json_bldgs.plot()

# %%
 App_datasets['death_date']
# Out:
# datetime.date(2036, 2, 2)
